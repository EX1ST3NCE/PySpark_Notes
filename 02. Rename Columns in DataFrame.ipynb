# %%
from pyspark.sql.functions import col

# %%
# File location and type
file_location = "/FileStore/tables/Data.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","


# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# %% [markdown]
# >####1. withColumnRenamed()

# %%
#Single Column

df = df.withColumnRenamed("Id", "ID_New")
display(df)

# Multiple column

df = df.withColumnRenamed("Id", "ID_New").withColumnRenamed("Name", "Name_New").withColumnRenamed("Age", "Age_New")
display(df)
# df.show()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_New</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>1</td><td>Nitin</td><td>25</td></tr><tr><td>2</td><td>Surya</td><td>26</td></tr><tr><td>3</td><td>Ravi</td><td>23</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# >####2.selectExpr()

# %%
df = df.selectExpr("ID_New as ID", "Name_New as Name", "Age_New as Age")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>1</td><td>Nitin</td><td>25</td></tr><tr><td>2</td><td>Surya</td><td>26</td></tr><tr><td>3</td><td>Ravi</td><td>23</td></tr></tbody></table></div>

# %% [markdown]
# >####3. Select Function with col

# %%
df = df.select(col("ID").alias("ID_New"), col("Name").alias("Name_New"), col("Age").alias("Age_New"))
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID_New</th><th>Name_New</th><th>Age_New</th></tr></thead><tbody><tr><td>1</td><td>Nitin</td><td>25</td></tr><tr><td>2</td><td>Surya</td><td>26</td></tr><tr><td>3</td><td>Ravi</td><td>23</td></tr></tbody></table></div>
